# %%
# !pip install transformers huggingface_hub
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /home/elicer/.local/lib/python3.10/site-packages (4.44.2)
# Requirement already satisfied: huggingface_hub in /home/elicer/.local/lib/python3.10/site-packages (0.26.0)
# Requirement already satisfied: filelock in /home/elicer/.local/lib/python3.10/site-packages (from transformers) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /home/elicer/.local/lib/python3.10/site-packages (from transformers) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in /home/elicer/.local/lib/python3.10/site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/elicer/.local/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/elicer/.local/lib/python3.10/site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /home/elicer/.local/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /home/elicer/.local/lib/python3.10/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/elicer/.local/lib/python3.10/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /home/elicer/.local/lib/python3.10/site-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/elicer/.local/lib/python3.10/site-packages (from huggingface_hub) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/elicer/.local/lib/python3.10/site-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/elicer/.local/lib/python3.10/site-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/elicer/.local/lib/python3.10/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/elicer/.local/lib/python3.10/site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/elicer/.local/lib/python3.10/site-packages (from requests->transformers) (2024.8.30)

# %%
# Unsloth 설치 및 최신 버전 업그레이드
# !pip install unsloth
# !pip uninstall unsloth -y && pip install --upgrade --no-cache-dir "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install trl bitsandbytes triton xformers peft

# GPU가 softcapping을 지원하는 경우, Flash Attention 2 설치
import torch
if torch.cuda.get_device_capability()[0] >= 8:
    # !pip install --no-deps packaging ninja einops "flash-attn>=2.6.3"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting unsloth
#   Downloading unsloth-2024.10.2-py3-none-any.whl.metadata (56 kB)
# Collecting unsloth-zoo (from unsloth)
#   Downloading unsloth_zoo-2024.10.4-py3-none-any.whl.metadata (48 kB)
# Collecting torch>=2.4.0 (from unsloth)
#   Downloading torch-2.5.0-cp310-cp310-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting xformers>=0.0.27.post2 (from unsloth)
#   Downloading xformers-0.0.28.post1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (1.0 kB)
# Collecting bitsandbytes (from unsloth)
#   Downloading bitsandbytes-0.44.1-py3-none-manylinux_2_24_x86_64.whl.metadata (3.5 kB)
# Collecting triton>=3.0.0 (from unsloth)
#   Downloading triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: packaging in /home/elicer/.local/lib/python3.10/site-packages (from unsloth) (24.1)
# Collecting tyro (from unsloth)
#   Downloading tyro-0.8.13-py3-none-any.whl.metadata (8.4 kB)
# Collecting transformers<4.45.0 (from unsloth)
#   Downloading transformers-4.44.2-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: datasets>=2.16.0 in /home/elicer/.local/lib/python3.10/site-packages (from unsloth) (3.0.1)
# Collecting sentencepiece>=0.2.0 (from unsloth)
#   Downloading sentencepiece-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: tqdm in /home/elicer/.local/lib/python3.10/site-packages (from unsloth) (4.66.5)
# Requirement already satisfied: psutil in /home/elicer/.local/lib/python3.10/site-packages (from unsloth) (6.1.0)
# Collecting wheel>=0.42.0 (from unsloth)
#   Downloading wheel-0.44.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy in /home/elicer/.local/lib/python3.10/site-packages (from unsloth) (2.1.2)
# Collecting accelerate>=0.34.1 (from unsloth)
#   Downloading accelerate-1.0.1-py3-none-any.whl.metadata (19 kB)
# Collecting trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.11.1,>=0.7.9 (from unsloth)
#   Downloading trl-0.11.1-py3-none-any.whl.metadata (12 kB)
# Collecting peft!=0.11.0,>=0.7.1 (from unsloth)
#   Downloading peft-0.13.2-py3-none-any.whl.metadata (13 kB)
# Collecting protobuf<4.0.0 (from unsloth)
#   Downloading protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (679 bytes)
# Requirement already satisfied: huggingface-hub in /home/elicer/.local/lib/python3.10/site-packages (from unsloth) (0.26.0)
# Collecting hf-transfer (from unsloth)
#   Downloading hf_transfer-0.1.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: pyyaml in /home/elicer/.local/lib/python3.10/site-packages (from accelerate>=0.34.1->unsloth) (6.0.2)
# Collecting safetensors>=0.4.3 (from accelerate>=0.34.1->unsloth)
#   Downloading safetensors-0.4.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: filelock in /home/elicer/.local/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/elicer/.local/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/elicer/.local/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (0.3.8)
# Requirement already satisfied: pandas in /home/elicer/.local/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in /home/elicer/.local/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (2.32.3)
# Requirement already satisfied: xxhash in /home/elicer/.local/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (3.5.0)
# Requirement already satisfied: multiprocess in /home/elicer/.local/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /home/elicer/.local/lib/python3.10/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets>=2.16.0->unsloth) (2024.6.1)
# Requirement already satisfied: aiohttp in /home/elicer/.local/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (3.10.10)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/elicer/.local/lib/python3.10/site-packages (from huggingface-hub->unsloth) (4.12.2)
# Collecting networkx (from torch>=2.4.0->unsloth)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in /home/elicer/.local/lib/python3.10/site-packages (from torch>=2.4.0->unsloth) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting sympy==1.13.1 (from torch>=2.4.0->unsloth)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch>=2.4.0->unsloth)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: regex!=2019.12.17 in /home/elicer/.local/lib/python3.10/site-packages (from transformers<4.45.0->unsloth) (2024.9.11)
# Collecting tokenizers<0.20,>=0.19 (from transformers<4.45.0->unsloth)
#   Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting docstring-parser>=0.16 (from tyro->unsloth)
#   Downloading docstring_parser-0.16-py3-none-any.whl.metadata (3.0 kB)
# Collecting rich>=11.1.0 (from tyro->unsloth)
#   Downloading rich-13.9.2-py3-none-any.whl.metadata (18 kB)
# Collecting shtab>=1.5.6 (from tyro->unsloth)
#   Downloading shtab-1.7.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting torch>=2.4.0 (from unsloth)
#   Downloading torch-2.4.1-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting sympy (from torch>=2.4.0->unsloth)
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12 (from nvidia-cudnn-cu12==9.1.0.70->torch>=2.4.0->unsloth)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12 (from nvidia-cusolver-cu12==11.6.1.9->torch>=2.4.0->unsloth)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton>=3.0.0 (from unsloth)
#   Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.4.0->unsloth)
#   Downloading nvidia_nvjitlink_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/elicer/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/elicer/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/elicer/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/elicer/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/elicer/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /home/elicer/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.15.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/elicer/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/elicer/.local/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/elicer/.local/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/elicer/.local/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/elicer/.local/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (2024.8.30)
# Collecting markdown-it-py>=2.2.0 (from rich>=11.1.0->tyro->unsloth)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/elicer/.local/lib/python3.10/site-packages (from rich>=11.1.0->tyro->unsloth) (2.18.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/elicer/.local/lib/python3.10/site-packages (from jinja2->torch>=2.4.0->unsloth) (3.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/elicer/.local/lib/python3.10/site-packages (from pandas->datasets>=2.16.0->unsloth) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/elicer/.local/lib/python3.10/site-packages (from pandas->datasets>=2.16.0->unsloth) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/elicer/.local/lib/python3.10/site-packages (from pandas->datasets>=2.16.0->unsloth) (2024.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro->unsloth)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: six>=1.5 in /home/elicer/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.16.0->unsloth) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/elicer/.local/lib/python3.10/site-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets>=2.16.0->unsloth) (0.2.0)
# Downloading unsloth-2024.10.2-py3-none-any.whl (163 kB)
# Downloading accelerate-1.0.1-py3-none-any.whl (330 kB)
# Downloading peft-0.13.2-py3-none-any.whl (320 kB)
# Downloading protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 49.1 MB/s eta 0:00:00
# Downloading sentencepiece-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 20.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 29.7 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 27.4 MB/s eta 0:00:00a 0:00:01
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 29.8 MB/s eta 0:00:00a 0:00:01
# Downloading transformers-4.44.2-py3-none-any.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 27.5 MB/s eta 0:00:00a 0:00:01
# Downloading trl-0.11.1-py3-none-any.whl (318 kB)
# Downloading tyro-0.8.13-py3-none-any.whl (109 kB)
# Downloading wheel-0.44.0-py3-none-any.whl (67 kB)
# Downloading xformers-0.0.28.post1-cp310-cp310-manylinux_2_28_x86_64.whl (16.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 16.9 MB/s eta 0:00:00a 0:00:01
# Downloading torch-2.4.1-cp310-cp310-manylinux1_x86_64.whl (797.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.1/797.1 MB 19.9 MB/s eta 0:00:0000:0100:02
# Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 20.1 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 25.9 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 24.3 MB/s eta 0:00:00a 0:00:01
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 26.9 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 15.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 26.7 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 27.6 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 33.0 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 29.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 26.8 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading bitsandbytes-0.44.1-py3-none-manylinux_2_24_x86_64.whl (122.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 22.5 MB/s eta 0:00:0000:0100:01
# Downloading hf_transfer-0.1.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 27.2 MB/s eta 0:00:00
# Downloading unsloth_zoo-2024.10.4-py3-none-any.whl (39 kB)
# Downloading docstring_parser-0.16-py3-none-any.whl (36 kB)
# Downloading rich-13.9.2-py3-none-any.whl (242 kB)
# Downloading safetensors-0.4.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (435 kB)
# Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 27.8 MB/s eta 0:00:00
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 19.9 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 13.8 MB/s eta 0:00:00
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: sentencepiece, mpmath, wheel, triton, sympy, shtab, safetensors, protobuf, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, mdurl, hf-transfer, docstring-parser, nvidia-cusparse-cu12, nvidia-cudnn-cu12, markdown-it-py, tokenizers, rich, nvidia-cusolver-cu12, tyro, transformers, torch, xformers, bitsandbytes, accelerate, trl, peft, unsloth-zoo, unsloth
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.20.1
#     Uninstalling tokenizers-0.20.1:
#       Successfully uninstalled tokenizers-0.20.1
# Successfully installed accelerate-1.0.1 bitsandbytes-0.44.1 docstring-parser-0.16 hf-transfer-0.1.8 markdown-it-py-3.0.0 mdurl-0.1.2 mpmath-1.3.0 networkx-3.4.2 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 peft-0.13.2 protobuf-3.20.3 rich-13.9.2 safetensors-0.4.5 sentencepiece-0.2.0 shtab-1.7.1 sympy-1.13.1 tokenizers-0.19.1 torch-2.4.1 transformers-4.44.2 triton-3.0.0 trl-0.11.1 tyro-0.8.13 unsloth-2024.10.2 unsloth-zoo-2024.10.4 wheel-0.44.0 xformers-0.0.28.post1
# Found existing installation: unsloth 2024.10.2
# Uninstalling unsloth-2024.10.2:
#   Successfully uninstalled unsloth-2024.10.2
# Defaulting to user installation because normal site-packages is not writeable
# Collecting unsloth@ git+https://github.com/unslothai/unsloth.git (from unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git)
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-iptx5exk/unsloth_fb6990e80295439cba22ce5b82af8082
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-iptx5exk/unsloth_fb6990e80295439cba22ce5b82af8082
#   Resolved https://github.com/unslothai/unsloth.git to commit 1f52468fa31bf0b641ec96217ef0f5916a07fce5
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: unsloth-zoo in /home/elicer/.local/lib/python3.10/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.10.4)
# Requirement already satisfied: packaging in /home/elicer/.local/lib/python3.10/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (24.1)
# Requirement already satisfied: tyro in /home/elicer/.local/lib/python3.10/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.8.13)
# Requirement already satisfied: transformers>=4.44.2 in /home/elicer/.local/lib/python3.10/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.44.2)
# Requirement already satisfied: datasets>=2.16.0 in /home/elicer/.local/lib/python3.10/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.0.1)
# Requirement already satisfied: sentencepiece>=0.2.0 in /home/elicer/.local/lib/python3.10/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.2.0)
# Requirement already satisfied: tqdm in /home/elicer/.local/lib/python3.10/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.66.5)
# Requirement already satisfied: psutil in /home/elicer/.local/lib/python3.10/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (6.1.0)
# Requirement already satisfied: wheel>=0.42.0 in /home/elicer/.local/lib/python3.10/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.44.0)
# Requirement already satisfied: numpy in /home/elicer/.local/lib/python3.10/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.1.2)
# Requirement already satisfied: protobuf<4.0.0 in /home/elicer/.local/lib/python3.10/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.20.3)
# Requirement already satisfied: huggingface-hub in /home/elicer/.local/lib/python3.10/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.26.0)
# Requirement already satisfied: hf-transfer in /home/elicer/.local/lib/python3.10/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.1.8)
# Requirement already satisfied: filelock in /home/elicer/.local/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/elicer/.local/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/elicer/.local/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.3.8)
# Requirement already satisfied: pandas in /home/elicer/.local/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in /home/elicer/.local/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.32.3)
# Requirement already satisfied: xxhash in /home/elicer/.local/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.5.0)
# Requirement already satisfied: multiprocess in /home/elicer/.local/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /home/elicer/.local/lib/python3.10/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.6.1)
# Requirement already satisfied: aiohttp in /home/elicer/.local/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.10.10)
# Requirement already satisfied: pyyaml>=5.1 in /home/elicer/.local/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/elicer/.local/lib/python3.10/site-packages (from huggingface-hub->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.12.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/elicer/.local/lib/python3.10/site-packages (from transformers>=4.44.2->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /home/elicer/.local/lib/python3.10/site-packages (from transformers>=4.44.2->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/elicer/.local/lib/python3.10/site-packages (from transformers>=4.44.2->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.19.1)
# Requirement already satisfied: docstring-parser>=0.16 in /home/elicer/.local/lib/python3.10/site-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /home/elicer/.local/lib/python3.10/site-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (13.9.2)
# Requirement already satisfied: shtab>=1.5.6 in /home/elicer/.local/lib/python3.10/site-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.7.1)
# Requirement already satisfied: torch in /home/elicer/.local/lib/python3.10/site-packages (from unsloth-zoo->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.4.1)
# Requirement already satisfied: triton in /home/elicer/.local/lib/python3.10/site-packages (from unsloth-zoo->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.0.0)
# Requirement already satisfied: accelerate>=0.34.1 in /home/elicer/.local/lib/python3.10/site-packages (from unsloth-zoo->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.0.1)
# Requirement already satisfied: trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.11.1,>=0.7.9 in /home/elicer/.local/lib/python3.10/site-packages (from unsloth-zoo->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.11.1)
# Requirement already satisfied: peft!=0.11.0,>=0.7.1 in /home/elicer/.local/lib/python3.10/site-packages (from unsloth-zoo->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.13.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/elicer/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/elicer/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/elicer/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/elicer/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/elicer/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /home/elicer/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.15.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/elicer/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/elicer/.local/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/elicer/.local/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/elicer/.local/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/elicer/.local/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/elicer/.local/lib/python3.10/site-packages (from rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/elicer/.local/lib/python3.10/site-packages (from rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.18.0)
# Requirement already satisfied: sympy in /home/elicer/.local/lib/python3.10/site-packages (from torch->unsloth-zoo->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.13.1)
# Requirement already satisfied: networkx in /home/elicer/.local/lib/python3.10/site-packages (from torch->unsloth-zoo->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.4.2)
# Requirement already satisfied: jinja2 in /home/elicer/.local/lib/python3.10/site-packages (from torch->unsloth-zoo->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/elicer/.local/lib/python3.10/site-packages (from torch->unsloth-zoo->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/elicer/.local/lib/python3.10/site-packages (from torch->unsloth-zoo->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/elicer/.local/lib/python3.10/site-packages (from torch->unsloth-zoo->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/elicer/.local/lib/python3.10/site-packages (from torch->unsloth-zoo->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/elicer/.local/lib/python3.10/site-packages (from torch->unsloth-zoo->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/elicer/.local/lib/python3.10/site-packages (from torch->unsloth-zoo->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/elicer/.local/lib/python3.10/site-packages (from torch->unsloth-zoo->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/elicer/.local/lib/python3.10/site-packages (from torch->unsloth-zoo->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/elicer/.local/lib/python3.10/site-packages (from torch->unsloth-zoo->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/elicer/.local/lib/python3.10/site-packages (from torch->unsloth-zoo->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/elicer/.local/lib/python3.10/site-packages (from torch->unsloth-zoo->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/elicer/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->unsloth-zoo->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.4.127)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/elicer/.local/lib/python3.10/site-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/elicer/.local/lib/python3.10/site-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/elicer/.local/lib/python3.10/site-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.2)
# Requirement already satisfied: mdurl~=0.1 in /home/elicer/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.1.2)
# Requirement already satisfied: six>=1.5 in /home/elicer/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/elicer/.local/lib/python3.10/site-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/elicer/.local/lib/python3.10/site-packages (from jinja2->torch->unsloth-zoo->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/elicer/.local/lib/python3.10/site-packages (from sympy->torch->unsloth-zoo->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.3.0)
# Building wheels for collected packages: unsloth
#   Building wheel for unsloth (pyproject.toml) ... done
#   Created wheel for unsloth: filename=unsloth-2024.10.3-py3-none-any.whl size=162561 sha256=6a34df6c318afae6ca27cfdf3355259ef22eb4cbbfedf03518126411d8bcb08f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qlfryoka/wheels/ed/d4/e9/76fb290ee3df0a5fc21ce5c2c788e29e9607a2353d8342fd0d
# Successfully built unsloth
# Installing collected packages: unsloth
# Successfully installed unsloth-2024.10.3
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: trl in /home/elicer/.local/lib/python3.10/site-packages (0.11.1)
# Requirement already satisfied: bitsandbytes in /home/elicer/.local/lib/python3.10/site-packages (0.44.1)
# Requirement already satisfied: triton in /home/elicer/.local/lib/python3.10/site-packages (3.0.0)
# Requirement already satisfied: xformers in /home/elicer/.local/lib/python3.10/site-packages (0.0.28.post1)
# Requirement already satisfied: peft in /home/elicer/.local/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: torch>=1.4.0 in /home/elicer/.local/lib/python3.10/site-packages (from trl) (2.4.1)
# Requirement already satisfied: transformers>=4.40.0 in /home/elicer/.local/lib/python3.10/site-packages (from trl) (4.44.2)
# Requirement already satisfied: accelerate in /home/elicer/.local/lib/python3.10/site-packages (from trl) (1.0.1)
# Requirement already satisfied: datasets in /home/elicer/.local/lib/python3.10/site-packages (from trl) (3.0.1)
# Requirement already satisfied: tyro>=0.5.11 in /home/elicer/.local/lib/python3.10/site-packages (from trl) (0.8.13)
# Requirement already satisfied: numpy>=1.18.2 in /home/elicer/.local/lib/python3.10/site-packages (from trl) (2.1.2)
# Requirement already satisfied: filelock in /home/elicer/.local/lib/python3.10/site-packages (from triton) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/elicer/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (4.12.2)
# Requirement already satisfied: sympy in /home/elicer/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (1.13.1)
# Requirement already satisfied: networkx in /home/elicer/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (3.4.2)
# Requirement already satisfied: jinja2 in /home/elicer/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (3.1.4)
# Requirement already satisfied: fsspec in /home/elicer/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/elicer/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/elicer/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/elicer/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/elicer/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/elicer/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/elicer/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/elicer/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/elicer/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/elicer/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/elicer/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/elicer/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/elicer/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.4.0->trl) (12.4.127)
# Requirement already satisfied: packaging>=20.0 in /home/elicer/.local/lib/python3.10/site-packages (from peft) (24.1)
# Requirement already satisfied: psutil in /home/elicer/.local/lib/python3.10/site-packages (from peft) (6.1.0)
# Requirement already satisfied: pyyaml in /home/elicer/.local/lib/python3.10/site-packages (from peft) (6.0.2)
# Requirement already satisfied: tqdm in /home/elicer/.local/lib/python3.10/site-packages (from peft) (4.66.5)
# Requirement already satisfied: safetensors in /home/elicer/.local/lib/python3.10/site-packages (from peft) (0.4.5)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /home/elicer/.local/lib/python3.10/site-packages (from peft) (0.26.0)
# Requirement already satisfied: requests in /home/elicer/.local/lib/python3.10/site-packages (from huggingface-hub>=0.17.0->peft) (2.32.3)
# Requirement already satisfied: regex!=2019.12.17 in /home/elicer/.local/lib/python3.10/site-packages (from transformers>=4.40.0->trl) (2024.9.11)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/elicer/.local/lib/python3.10/site-packages (from transformers>=4.40.0->trl) (0.19.1)
# Requirement already satisfied: docstring-parser>=0.16 in /home/elicer/.local/lib/python3.10/site-packages (from tyro>=0.5.11->trl) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /home/elicer/.local/lib/python3.10/site-packages (from tyro>=0.5.11->trl) (13.9.2)
# Requirement already satisfied: shtab>=1.5.6 in /home/elicer/.local/lib/python3.10/site-packages (from tyro>=0.5.11->trl) (1.7.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/elicer/.local/lib/python3.10/site-packages (from datasets->trl) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/elicer/.local/lib/python3.10/site-packages (from datasets->trl) (0.3.8)
# Requirement already satisfied: pandas in /home/elicer/.local/lib/python3.10/site-packages (from datasets->trl) (2.2.3)
# Requirement already satisfied: xxhash in /home/elicer/.local/lib/python3.10/site-packages (from datasets->trl) (3.5.0)
# Requirement already satisfied: multiprocess in /home/elicer/.local/lib/python3.10/site-packages (from datasets->trl) (0.70.16)
# Requirement already satisfied: aiohttp in /home/elicer/.local/lib/python3.10/site-packages (from datasets->trl) (3.10.10)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/elicer/.local/lib/python3.10/site-packages (from aiohttp->datasets->trl) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/elicer/.local/lib/python3.10/site-packages (from aiohttp->datasets->trl) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/elicer/.local/lib/python3.10/site-packages (from aiohttp->datasets->trl) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/elicer/.local/lib/python3.10/site-packages (from aiohttp->datasets->trl) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/elicer/.local/lib/python3.10/site-packages (from aiohttp->datasets->trl) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /home/elicer/.local/lib/python3.10/site-packages (from aiohttp->datasets->trl) (1.15.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/elicer/.local/lib/python3.10/site-packages (from aiohttp->datasets->trl) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/elicer/.local/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/elicer/.local/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/elicer/.local/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/elicer/.local/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/elicer/.local/lib/python3.10/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/elicer/.local/lib/python3.10/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (2.18.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/elicer/.local/lib/python3.10/site-packages (from jinja2->torch>=1.4.0->trl) (3.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/elicer/.local/lib/python3.10/site-packages (from pandas->datasets->trl) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/elicer/.local/lib/python3.10/site-packages (from pandas->datasets->trl) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/elicer/.local/lib/python3.10/site-packages (from pandas->datasets->trl) (2024.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/elicer/.local/lib/python3.10/site-packages (from sympy->torch>=1.4.0->trl) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /home/elicer/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl) (0.1.2)
# Requirement already satisfied: six>=1.5 in /home/elicer/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets->trl) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/elicer/.local/lib/python3.10/site-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets->trl) (0.2.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: packaging in /home/elicer/.local/lib/python3.10/site-packages (24.1)
# Collecting ninja
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl.metadata (5.3 kB)
# Collecting einops
#   Downloading einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Collecting flash-attn>=2.6.3
#   Downloading flash_attn-2.6.3.tar.gz (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 66.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Using cached ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
# Downloading einops-0.8.0-py3-none-any.whl (43 kB)
# Building wheels for collected packages: flash-attn
#   Building wheel for flash-attn (setup.py) ... done
#   Created wheel for flash-attn: filename=flash_attn-2.6.3-cp310-cp310-linux_x86_64.whl size=187309225 sha256=237ef9c6157db394e1ddde4ba609a21ebb98382377a27041edc09318801a6f24
#   Stored in directory: /home/elicer/.cache/pip/wheels/7e/e3/c3/89c7a2f3c4adc07cd1c675f8bb7b9ad4d18f64a72bccdfe826
# Successfully built flash-attn
# Installing collected packages: ninja, flash-attn, einops
# Successfully installed einops-0.8.0 flash-attn-2.6.3 ninja-1.11.1.1

# %%
from dotenv import load_dotenv
from huggingface_hub import login
import os

load_dotenv()
hftoken = os.getenv("HUGGINGFACE_TOKEN")
login(hftoken)

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048
dtype = None # None으로 지정할 경우 해당 컴퓨팅 유닛에 알맞은 dtype으로 저장됩니다. Tesla T4와 V100의 경우에는 Float16, Ampere+ 이상의 경우에는 Bfloat16으로 설정됩니다.
load_in_4bit = True # 메모리 사용량을 줄이기 위해서는 4bit 양자화를 사용하실 것을 권장합니다.

# 모델 및 토크나이저 선언
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Qwen2-7B-Instruct",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    # token = "hf_...", # gated model을 사용할 경우 허깅페이스 토큰을 입력해주시길 바라겠습니다.
)
# LoRA Adapter 선언
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # 0을 넘는 숫자를 선택하세요. 8, 16, 32, 64, 128이 추천됩니다.
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",], # target module도 적절하게 조정할 수 있습니다.
    lora_alpha = 16,
    lora_dropout = 0, # 어떤 값이든 사용될 수 있지만, 0으로 최적화되어 있습니다.
    bias = "none",    # 어떤 값이든 사용될 수 있지만, "none"으로 최적화되어 있습니다.
    use_gradient_checkpointing = "unsloth", # 매우 긴 context에 대해 True 또는 "unsloth"를 사용하십시오.
    random_state = 42,
    use_rslora = False,
    loftq_config = None
)
prompt_format = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Response:
{}"""

EOS_TOKEN = tokenizer.eos_token
def formatting_prompts_func(examples):
    instructions = examples["text"]
    outputs = examples["text"]
    texts = []
    for instruction, output in zip(instructions, outputs):
        text = prompt_format.format(instruction, output) + EOS_TOKEN # 마지막에 eos token을 추가해줌으로써 모델이 출력을 끝마칠 수 있게 만들어 줍니다.
        texts.append(text)
    return { "formatted_text" : texts, }
pass

from datasets import load_dataset
dataset = load_dataset("Linq-AI-Research/FinanceRAG",'FinQABench', split = "corpus")
dataset = dataset.map(formatting_prompts_func, batched = True,)
dataset
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "formatted_text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False, # True로 설정하면 짧은 텍스트 데이터에 대해서는 더 빠른 학습 속도로를 보여줍니다.
    args = TrainingArguments( # TrainingArguments는 자신의 학습 환경과 기호에 따라 적절하게 설정하면 됩니다.
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        # num_train_epochs = 1,
        max_steps = 60,
        learning_rate = 2e-4,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 42,
        output_dir = "outputs",
    ),
)
FastLanguageModel.for_inference(model)
inputs = tokenizer(
[
    prompt_format.format(
        "다음 중 화폐의 시간가치에 관한 설명으로 옳지 않은 것은 무엇인가? A. 월 복리의 경우, 매월 적용되는 이자율은 연간 명목 이자율을 1/12로 나누어 산출한다. B. 투자 원금 및 기타 조건이 동일할 경우, 단리 방식보다 복리 방식에서 발생하는 이자가 더 크다. C. 일시불로 지급될 금액의 현재 가치는 미래 가치를 일정 기간 동안 할인율을 적용해 산출할 수 있다. D. 1,000,000원을 연 5% 복리로 2년 동안 예치했을 경우, 만기에 받을 세전 이자는 100,000원이다..", # instruction
        "", # output 생성을 위해 빈 칸으로 설정
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 256, use_cache = True)
print(tokenizer.batch_decode(outputs))
for item in tokenizer.batch_decode(outputs):
    print(item)
# Out:
# ==((====))==  Unsloth 2024.10.3: Fast Qwen2 patching. Transformers = 4.44.2.
#    \\   /|    GPU: NVIDIA A100 80GB PCIe MIG 3g.40gb. Max memory: 39.5 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.4.1+cu121. CUDA = 8.0. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post1. FA2 = True]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# max_steps is given, it will override any value given in num_train_epochs
# ['Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.\n\n### Instruction:\n다음 중 화폐의 시간가치에 관한 설명으로 옳지 않은 것은 무엇인가? A. 월 복리의 경우, 매월 적용되는 이자율은 연간 명목 이자율을 1/12로 나누어 산출한다. B. 투자 원금 및 기타 조건이 동일할 경우, 단리 방식보다 복리 방식에서 발생하는 이자가 더 크다. C. 일시불로 지급될 금액의 현재 가치는 미래 가치를 일정 기간 동안 할인율을 적용해 산출할 수 있다. D. 1,000,000원을 연 5% 복리로 2년 동안 예치했을 경우, 만기에 받을 세전 이자는 100,000원이다..\n\n### Response:\nD. 1,000,000원을 연 5% 복리로 2년 동안 예치했을 경우, 만기에 받을 세전 이자는 100,000원이다.. \n\nThis statement is incorrect because if you invest 1,000,000원 at a 5% annual compound interest rate for 2 years, the total interest earned before taxes would be more than 100,000원. The formula to calculate compound interest is: A = P( * (1 + r/n )^(nt) - P, where A is the amount of money accumulated after n years, including interest, P is the principal amount (the initial amount of money), r is the annual interest rate (decimal), n is the number of times that interest is compounded per year, and t is the time the money is invested for in years. In this case, with yearly compounding (n=1), the total amount after 2 years would be more than 1,000,000원, meaning the interest earned would also be more than 100,000원.<|im_end|>']
# Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# 다음 중 화폐의 시간가치에 관한 설명으로 옳지 않은 것은 무엇인가? A. 월 복리의 경우, 매월 적용되는 이자율은 연간 명목 이자율을 1/12로 나누어 산출한다. B. 투자 원금 및 기타 조건이 동일할 경우, 단리 방식보다 복리 방식에서 발생하는 이자가 더 크다. C. 일시불로 지급될 금액의 현재 가치는 미래 가치를 일정 기간 동안 할인율을 적용해 산출할 수 있다. D. 1,000,000원을 연 5% 복리로 2년 동안 예치했을 경우, 만기에 받을 세전 이자는 100,000원이다..
#
# ### Response:
# D. 1,000,000원을 연 5% 복리로 2년 동안 예치했을 경우, 만기에 받을 세전 이자는 100,000원이다..
#
# This statement is incorrect because if you invest 1,000,000원 at a 5% annual compound interest rate for 2 years, the total interest earned before taxes would be more than 100,000원. The formula to calculate compound interest is: A = P( * (1 + r/n )^(nt) - P, where A is the amount of money accumulated after n years, including interest, P is the principal amount (the initial amount of money), r is the annual interest rate (decimal), n is the number of times that interest is compounded per year, and t is the time the money is invested for in years. In this case, with yearly compounding (n=1), the total amount after 2 years would be more than 1,000,000원, meaning the interest earned would also be more than 100,000원.<|im_end|>

# %%
# LoRA Adapter 저장
model.save_pretrained("lora_model")
tokenizer.save_pretrained("lora_model")

# Merged model 저장 및 업로드
model.save_pretrained_merged("model", tokenizer, save_method = "merged_16bit",)
model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_16bit", token = hftoken) # 개인 huggingface token을 사용하여 업로드할 수 있습니다.
